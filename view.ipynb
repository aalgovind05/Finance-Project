# %%
import pandas as pd

# Quick peek — don't load everything yet
chunk = pd.read_csv(r"C:\Users\aalgo\fin Project\archive\accepted_2007_to_2018Q4.csv.gz", compression='gzip', nrows=5000)

print(chunk.shape)
print(chunk.columns.tolist())
print(chunk['loan_status'].value_counts())
print(chunk.dtypes)
# Out:
# (5000, 151)
# ...

# %%
chunk.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.99       123.03     C        C4  ...                            NaN
# 1     11.99       820.28     C        C1  ...                            NaN
# 2     10.78       432.66     B        B4  ...                            NaN
# 3     14.85       829.90     C        C5  ...                            NaN
# 4     22.45       289.91     F        F1  ...                            NaN
#
# ...

# %%
chunk.info
# Out:
# <bound method DataFrame.info of             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0     68407277        NaN     3600.0       3600.0           3600.0
# 1     68355089        NaN    24700.0      24700.0          24700.0
# 2     68341763        NaN    20000.0      20000.0          20000.0
# 3     66310712        NaN    35000.0      35000.0          35000.0
# 4     68476807        NaN    10400.0      10400.0          10400.0
# ...        ...        ...        ...          ...              ...
# 4995  67635995        NaN     6000.0       6000.0           6000.0
# 4996  68583457        NaN    21600.0      21600.0          21600.0
# 4997  68433410        NaN     4800.0       4800.0           4800.0
# 4998  68533531        NaN    16275.0      16275.0          16275.0
# 4999  66320160        NaN    10000.0      10000.0          10000.0
#
#             term  int_rate  installment grade sub_grade  ...  \
# 0      36 months     13.99       123.03     C        C4  ...
# ...

# %%
chunk.describe()
# Out:
#                  id  member_id    loan_amnt  funded_amnt  funded_amnt_inv  \
# count  5.000000e+03        0.0   5000.00000   5000.00000       5000.00000
# mean   6.828371e+07        NaN  15234.35000  15234.35000      15232.78000
# std    1.717957e+06        NaN   8647.19714   8647.19714       8645.71224
# min    3.617740e+05        NaN   1000.00000   1000.00000       1000.00000
# 25%    6.836632e+07        NaN   8400.00000   8400.00000       8400.00000
# 50%    6.844592e+07        NaN  14150.00000  14150.00000      14150.00000
# 75%    6.853612e+07        NaN  20000.00000  20000.00000      20000.00000
# max    6.861706e+07        NaN  35000.00000  35000.00000      35000.00000
#
#           int_rate  installment     annual_inc          dti  delinq_2yrs  ...  \
# count  5000.000000  5000.000000    5000.000000  5000.000000  5000.000000  ...
# mean     12.308078   445.704526   78980.705004    19.291466     0.349400  ...
# ...

# %%
chunk.isnull().sum()
# Out:
# id                          0
# member_id                5000
# loan_amnt                   0
# funded_amnt                 0
# funded_amnt_inv             0
#                          ...
# settlement_status        4867
# settlement_date          4867
# settlement_amount        4867
# settlement_percentage    4867
# settlement_term          4867
# Length: 151, dtype: int64

# %%
chunk.shape
# Out:
# (5000, 151)

# %%
chunk.columns.tolist()
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'fico_range_low',
#  'fico_range_high',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'last_fico_range_high',
#  'last_fico_range_low',
# ...

# %%
chunk['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid            3637
# Charged Off            816
# Current                514
# Late (31-120 days)      29
# In Grace Period          3
# Late (16-30 days)        1
# Name: count, dtype: int64

# %%
chunk.dtypes
# Out:
# id                         int64
# member_id                float64
# loan_amnt                float64
# funded_amnt              float64
# funded_amnt_inv          float64
#                           ...
# settlement_status            str
# settlement_date              str
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# Length: 151, dtype: object

# %%
chunk.size
# Out:
# 755000

# %%
chunk.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.99       123.03     C        C4  ...                            NaN
# 1     11.99       820.28     C        C1  ...                            NaN
# 2     10.78       432.66     B        B4  ...                            NaN
# 3     14.85       829.90     C        C5  ...                            NaN
# 4     22.45       289.91     F        F1  ...                            NaN
#
# ...

# %%
chunk['member_id'].va
# Out:
# Series([], Name: count, dtype: int64)

# %%
chunk2 = chunk

# %%
chunk2.head()
# Out:
# Empty DataFrame
# ...

# %%
chunk.dropna(subset=['member_id'], inplace=True)

# %%
chunk2.head()
# Out:
# Empty DataFrame
# ...
